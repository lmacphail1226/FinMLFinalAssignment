# %% [markdown]
# ### Select Assets based on highest aggregate Sharpe Ratio

# %%
import pandas as pd
import numpy as np
import cvxpy as cp

# Load the data
df_input = pd.read_csv("etf_sharpe_summary_filtered.csv")
df_input = df_input.dropna(subset=['5Y Sharpe Ratio'])

# Sort to find top 3 Sharpe ETFs
df_input = df_input.sort_values(by='5Y Sharpe Ratio', ascending=False).reset_index(drop=True)
df_input['Top3'] = 0
df_input.loc[:2, 'Top3'] = 1  # mark top 3

tickers = df_input['Ticker'].values
classes = df_input['Class'].values
sharpe = df_input['5Y Sharpe Ratio'].values
top3_flags = df_input['Top3'].values
n = len(tickers)

# Define desired ETF count range
min_etfs = 20
max_etfs = 40

# Class-level bounds on number of selected ETFs
class_bounds = {
    'Equities': (0.30, 0.40),
    'Fixed Income': (0.30, 0.40),
    'Alternatives': (0.10, 0.15),
    'Liquidity': (0.15, 0.15),
    'Blended / Multi-Asset': (0.00, 0.10)
}

# Optimization variables
w = cp.Variable(n)
z = cp.Variable(n, boolean=True)

# Constraints
constraints = [
    cp.sum(w) == 1,
    w >= (1 / max_etfs) * z,  # min 1/n if selected
    cp.sum(z) >= min_etfs,
    cp.sum(z) <= max_etfs
]

# ETF-level max weight: 8% for top 3, 5% for others
for i in range(n):
    max_wt = 0.08 if top3_flags[i] == 1 else 0.05
    constraints.append(w[i] <= max_wt * z[i])

# Class-based selection count constraints
for cls, (min_frac, max_frac) in class_bounds.items():
    idx = np.where(classes == cls)[0]
    if len(idx) > 0:
        constraints += [
            cp.sum(z[idx]) >= min_frac * min_etfs,
            cp.sum(z[idx]) <= max_frac * max_etfs
        ]

# Objective: maximize weighted Sharpe Ratio
objective = cp.Maximize(sharpe @ w)

# Solve the problem
problem = cp.Problem(objective, constraints)

try:
    problem.solve(solver=cp.GLPK_MI)
    df_input['Weight'] = w.value
    df_output = df_input[df_input['Weight'] > 0.001].sort_values(by='Weight', ascending=False)
    df_output.to_csv("final_portfolio_top3_exception.csv", index=False)
    print("✅ Optimization complete. Saved to final_portfolio_top3_exception.csv")
except Exception as e:
    print("❌ Optimization failed:", e)
# Out:
# ✅ Optimization complete. Saved to final_portfolio_top3_exception.csv

# %%
df_output
# Out:
#     Ticker                             Name                    Category  \
# 0      DXJ  WisdomTree Japan Hedged Equity                  Japan Stock
# 1     OPPJ  WisdomTree Japan Opportunities                  Japan Stock
# 2    WDTRF  WISDOMTREE ISSUER ICAV WISDOMTR                         NaN
# 3     DBJP  Xtrackers MSCI Japan Hedged Equ                 Japan Stock
# 4      TPZ   Tortoise Essential Energy Fund               Equity Energy
# 5     ATMP             iPath Select MLP ETN  Energy Limited Partnership
# 6     GREK         Global X MSCI Greece ETF        Miscellaneous Region
# 7      UMI  USCF Midstream Energy Income Fu  Energy Limited Partnership
# 8     VRIG  Invesco Variable Rate Investmen             Ultrashort Bond
# 9     MLPX  Global X MLP & Energy Infrastru  Energy Limited Partnership
# 10    AAAU  Goldman Sachs Physical Gold ETF         Commodities Focused
# 11    EINC         VanEck Energy Income ETF  Energy Limited Partnership
# 12    ENFR  Alerian Energy Infrastructure E  Energy Limited Partnership
# 13    POCT  Innovator U.S. Equity Power Buf             Defined Outcome
# 32    PULS        PGIM Ultra Short Bond ETF             Ultrashort Bond
# 33    USFR  WisdomTree Floating Rate Treasu             Ultrashort Bond
# 36     TMV  Direxion Daily 20-Year Treasury       Trading--Inverse Debt
# 41    GLDI  ETRACS Gold Shares Covered Call         Commodities Focused
# 43    FLRN  SPDR Bloomberg Investment Grade             Ultrashort Bond
# 52    FLOT   iShares Floating Rate Bond ETF             Ultrashort Bond
# 145  CGBLF  ISHARES GOLD BULLION ETF UNITS                          NaN
# 320   GCOW  Pacer Global Cash Cows Dividend    Global Large-Stock Value
# 572   COWZ       Pacer US Cash Cows 100 ETF               Mid-Cap Value
# 627    BUL    Pacer US Cash Cows Growth ETF               Mid-Cap Blend
#
#             Class  5Y Sharpe Ratio  Top3  Weight
# 0        Equities         1.427509     1   0.080
# 1        Equities         1.387540     1   0.080
# 2        Equities         1.308969     1   0.080
# 3        Equities         1.118609     0   0.050
# 4        Equities         1.112126     0   0.050
# 5        Equities         1.078232     0   0.050
# 6        Equities         0.983368     0   0.050
# 7        Equities         0.980129     0   0.050
# 8    Fixed Income         0.974722     0   0.050
# 9        Equities         0.970743     0   0.050
# 10       Equities         0.957418     0   0.050
# 11       Equities         0.939929     0   0.050
# 12       Equities         0.912832     0   0.035
# 13       Equities         0.912399     0   0.025
# 32   Fixed Income         0.787723     0   0.025
# 33   Fixed Income         0.778736     0   0.025
# 36   Fixed Income         0.743764     0   0.025
# 41   Alternatives         0.730846     0   0.025
# 43   Fixed Income         0.723030     0   0.025
# 52   Fixed Income         0.709672     0   0.025
# 145  Alternatives         0.573532     0   0.025
# 320     Liquidity         0.466725     0   0.025
# 572     Liquidity         0.348666     0   0.025
# 627     Liquidity         0.319118     0   0.025
