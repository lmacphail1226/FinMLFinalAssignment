# %% [markdown]
# ### Import ETF List

# %%
import sys
import os

# src path
src_path = os.path.abspath(os.path.join("..", "src"))

# import src files
sys.path.append(src_path)
from data_collection import *

etf_df = pd.read_csv("polygon_etf_list.csv")

# %% [markdown]
# ### Create CSV Files from Start to End Date

# %%
create_5yr_data("2014-01-01","2018-12-31",etf_df)
# Out:
# File 'etf_monthly_metrics_2014_2018.csv' does not exist.
# File 'etf_sharpe_summary_2014_2018.csv' does not exist.
#
# 📦 Batch 1 — Downloading 400 ETFs...
# 315 Failed downloads:
# ['AVES', 'AMSPF', 'AFIX', 'AAUS', 'ASCE', 'ADIV', 'AVIG', 'AUSM', 'ACLC', 'BJUN', 'BELT', 'BITY', 'BITO', 'ARMU', 'BKCH', 'BDIV', 'BKHY', 'AUGZ', 'AFLG', 'BGIG', 'AAPX', 'BINC', 'ALLW', 'BCHP']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# ...
